# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("data/Japan_Visitor_Data.csv")
df["t"] = np.arange(len(df))
cutoff = 24
x = df.copy().iloc[0:-cutoff]
y = df.copy().iloc[-cutoff:]

# %%
# Creating crappy thing
import statsmodels.formula.api as smf

model = smf.ols('Daily_Visitors ~ t', data=x).fit()

# %%
import seaborn as sns

sns.regplot(x='t', y='Daily_Visitors', data=x)
# Out:
# <AxesSubplot: xlabel='t', ylabel='Daily_Visitors'>

# %% [markdown]
# I'm going to switch to R now because it's easier to analyze things that way
